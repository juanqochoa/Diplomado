# %%
import pandas as pd

# %% [markdown]
# Se va a utilizar una base de datos con información de presas de distintos países para hacer el análisis.

# %%
#Lectura de los datos

df = pd.read_csv("Dams.csv")
pd.set_option("display.max_columns", None) #Que muestre todas las columnas
df
# Out:
#      Reservior name       dam name                 river       main basin  \
# 0               NaN    Terror Lake          Terror River              NaN
# 1               NaN           Mayo                  Mayo              NaN
# 2               NaN      Blue Lake         Sawmill Creek              NaN
# 3               NaN     Green Lake         Vodopad River              NaN
# 4         Long Lake  Long Lake Dam            Long River              NaN
# ...             ...            ...                   ...              ...
# 6857            NaN        Torquay                Orange           Orange
# 6858            NaN         Laxiwa              Huang He         Huang He
# 6859            NaN       Tokuyama                   Ibi  Kiso Ibi Nagara
# 6860            NaN       Changyan  Trib. Dongyang Jiang   Qiantang Jiang
# 6861            NaN         Taylor                Taylor           Taylor
#
#      sub basin   near city administration city        COUNTRY  \
# ...

# %%
#Eliminar columnas que no brindan información
valores_unicos_n = df.nunique()
columnas_sn_info = valores_unicos_n[valores_unicos_n == 1].index.tolist()
columnas_sn_info
#La columna MULTI_DAMS no proporciona información valiosa
# Out:
# ['MULTI_DAMS,C,10']

# %%
df_clean = df.drop(columnas_sn_info, axis=1) #Se crea un data frame sin la columna que no provee información
df_clean.describe()
# Out:
#               YEAR   dam height    dam length    AREA(sqkm)  AREA(polygonal)  \
# count  6862.000000  6862.000000   6862.000000   6862.000000      6862.000000
# mean   1837.159429    35.608277    855.249636     65.643661        61.632746
# std     488.498946    49.951746   2481.859712   1018.168099       971.135385
# min     -99.000000   -99.000000    -99.000000    -99.000000       -99.000000
# 25%    1942.000000    18.000000     97.000000      1.300000         1.300000
# 50%    1963.000000    34.000000    311.000000      3.900000         3.800000
# 75%    1976.000000    57.000000    655.750000     13.800000        13.600000
# max    2010.000000   335.000000  80000.000000  67165.500000     67165.500000
#
#        CAPITAL EXPENDITURE     DEPTH(m)  AVG DISPLACEMENT OF WATER  \
# count          6862.000000  6862.000000               6.862000e+03
# mean            902.984859    25.486243               8.922279e+04
# std            6405.045839    34.165443               5.262096e+05
# ...

# %% [markdown]
# Separando los datos según el país de localización de las presas:

# %%
presas_US = df_clean[df_clean["COUNTRY"] == "United States"]
presas_Canada = df_clean[df_clean["COUNTRY"] == "Canada"]

# %%
presas_US.describe()
# Out:
#               YEAR   dam height    dam length   AREA(sqkm)  AREA(polygonal)  \
# count  1902.000000  1902.000000   1902.000000  1902.000000      1902.000000
# mean   1915.502103    31.914826   1126.650368    21.667087        21.568402
# std     252.220791    29.406672   2199.980527    76.672608        76.727240
# min     -99.000000     2.000000    -99.000000   -99.000000       -99.000000
# 25%    1927.000000    12.000000    220.000000     2.200000         2.200000
# 50%    1952.000000    25.000000    526.500000     5.000000         4.900000
# 75%    1967.000000    43.000000    979.500000    14.150000        13.950000
# max    2000.000000   235.000000  27763.000000  1418.800000      1418.800000
#
#        CAPITAL EXPENDITURE     DEPTH(m)  AVG DISPLACEMENT OF WATER  \
# count          1902.000000  1902.000000               1.902000e+03
# mean            381.982177    22.362723               3.389844e+04
# std            1686.007514    36.049469               1.770410e+05
# ...

# %%
presas_Canada.describe()
# Out:
#               YEAR  dam height    dam length    AREA(sqkm)  AREA(polygonal)  \
# count   225.000000  225.000000    225.000000    225.000000       225.000000
# mean   1928.715556   34.422222   1324.373333    432.892889       322.623111
# std     237.174832   48.088037   2809.146187   2221.711791      1462.250914
# min     -99.000000  -99.000000    -99.000000    -99.000000       -99.000000
# 25%    1942.000000   18.000000    279.000000      5.200000         5.200000
# 50%    1956.000000   26.000000    533.000000     20.800000        20.800000
# 75%    1970.000000   49.000000   1149.000000    111.200000       111.200000
# max    2008.000000  243.000000  25885.000000  25413.000000     19347.000000
#
#        CAPITAL EXPENDITURE    DEPTH(m)  AVG DISPLACEMENT OF WATER  \
# count           225.000000  225.000000               2.250000e+02
# mean           3817.063111   19.194667               3.446766e+05
# std           13413.525362   32.795334               9.191656e+05
# ...

# %%
#Resumen de información de las columnas para las presas de EEUU
presas_US.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 1902 entries, 0 to 6827
# Data columns (total 23 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   Reservior name             878 non-null    object
#  1   dam name                   1899 non-null   object
#  2   river                      1877 non-null   object
#  3   main basin                 0 non-null      object
#  4   sub basin                  0 non-null      object
#  5   near city                  3 non-null      object
#  6   administration city        1902 non-null   object
#  7   COUNTRY                    1902 non-null   object
#  8   secondary country          3 non-null      object
#  9   YEAR                       1902 non-null   int64
#  10  dam height                 1902 non-null   int64
#  11  dam length                 1902 non-null   int64
#  12  AREA(sqkm)                 1902 non-null   float64
# ...

# %%
# Se eliminan las columnas main basin, sub basin y timeline, debido a que tienen solamente valores nulos
presas_US_clean = df.drop(["main basin", "sub basin", "TIMELINE(status)"], axis=1)
presas_US_clean.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6862 entries, 0 to 6861
# Data columns (total 21 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   Reservior name             1930 non-null   object
#  1   dam name                   6839 non-null   object
#  2   river                      6501 non-null   object
#  3   near city                  4122 non-null   object
#  4   administration city        5224 non-null   object
#  5   COUNTRY                    6862 non-null   object
#  6   secondary country          47 non-null     object
#  7   YEAR                       6862 non-null   int64
#  8   dam height                 6862 non-null   int64
#  9   dam length                 6862 non-null   int64
#  10  AREA(sqkm)                 6862 non-null   float64
#  11  AREA(polygonal)            6862 non-null   float64
#  12  CAPITAL EXPENDITURE        6862 non-null   float64
# ...
